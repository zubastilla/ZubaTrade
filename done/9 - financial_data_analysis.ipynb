# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
start = '2014-10-01'
end = '2021-05-31'
symbol = 'BA'

# %%
df = yf.download(symbol,start,end)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2014-10-01 127.370003 127.370003 124.309998 124.669998 108.406662   5265200
# 2014-10-02 124.400002 125.550003 123.839996 124.169998 107.971916   3204500
# 2014-10-03 124.660004 126.870003 124.660004 126.360001 109.876198   3075900
# 2014-10-06 127.089996 127.190002 125.379997 126.260002 109.789261   2681000
# 2014-10-07 125.519997 125.519997 123.290001 123.320000 107.232780   3554900
# ...               ...        ...        ...        ...        ...       ...
# 2021-05-24 235.139999 238.500000 232.600006 237.440002 237.440002  10106000
# 2021-05-25 240.000000 243.779999 239.229996 240.740005 240.740005  12908000
# 2021-05-26 241.699997 242.490005 239.869995 241.369995 241.369995   7240200
# 2021-05-27 248.110001 252.600006 247.190002 250.699997 250.699997  18404400
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1677 entries, 2014-10-01 to 2021-05-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1677 non-null   float64
#  1   High       1677 non-null   float64
#  2   Low        1677 non-null   float64
#  3   Close      1677 non-null   float64
#  4   Adj Close  1677 non-null   float64
#  5   Volume     1677 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 91.7 KB

# %%
symbol = ['BA', 'MSFT','^DJI','EURUSD=X','GC=F','BTC-USD']

# %%
df = yf.download(symbol,start,end)
df
# Out:
# [*********************100%***********************]  6 of 6 completed
#             Adj Close                                               \
#                    BA      BTC-USD EURUSD=X        GC=F       MSFT
# Date
# 2014-10-01 108.406677   383.614990 1.262834 1214.599976  40.099861
# 2014-10-02 107.971893   375.071991 1.262419 1214.199951  39.977543
# 2014-10-03 109.876190   359.511993 1.267058 1192.199951  40.265850
# 2014-10-04        NaN   328.865997      NaN         NaN        NaN
# 2014-10-05        NaN   320.510010      NaN         NaN        NaN
# ...               ...          ...      ...         ...        ...
# 2021-05-27 250.699997 38436.968750 1.219260 1895.699951 247.866714
# 2021-05-28 247.020004 35697.605469 1.219319 1902.500000 248.234558
# 2021-05-29        NaN 34616.066406      NaN         NaN        NaN
# 2021-05-30        NaN 35678.128906      NaN         NaN        NaN
# 2021-05-31        NaN 37332.855469 1.219007         NaN        NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2435 entries, 2014-10-01 to 2021-05-31
# Freq: D
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, BA)        1677 non-null   float64
#  1   (Adj Close, BTC-USD)   2435 non-null   float64
#  2   (Adj Close, EURUSD=X)  1736 non-null   float64
#  3   (Adj Close, GC=F)      1674 non-null   float64
#  4   (Adj Close, MSFT)      1677 non-null   float64
#  5   (Adj Close, ^DJI)      1677 non-null   float64
#  6   (Close, BA)            1677 non-null   float64
#  7   (Close, BTC-USD)       2435 non-null   float64
#  8   (Close, EURUSD=X)      1736 non-null   float64
#  9   (Close, GC=F)          1674 non-null   float64
#  10  (Close, MSFT)          1677 non-null   float64
#  11  (Close, ^DJI)          1677 non-null   float64
#  12  (High, BA)             1677 non-null   float64
# ...

# %%
# Initial Inspection and Vusualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:4f}'.format
plt.style.use('seaborn')

# %%
df.Close.BA
df.loc[:,('Close','BA')]
df.loc['2015-01-07']
df.loc['2015']
df.loc['2020-06':,('Close','BA')]
# Out:
# Date
# 2020-06-01   151.389999
# 2020-06-02   153.309998
# 2020-06-03   173.160004
# 2020-06-04   184.300003
# 2020-06-05   205.429993
#                 ...
# 2021-05-27   250.699997
# 2021-05-28   247.020004
# 2021-05-29          NaN
# 2021-05-30          NaN
# 2021-05-31          NaN
# Freq: D, Name: (Close, BA), Length: 365, dtype: float64

# %%
# swap outer and inner index
df = df.swaplevel(axis='columns').sort_index(axis='columns')
df
# Out:
#                    BA                                              \
#             Adj Close      Close       High        Low       Open
# Date
# 2014-10-01 108.406677 124.669998 127.370003 124.309998 127.370003
# 2014-10-02 107.971893 124.169998 125.550003 123.839996 124.400002
# 2014-10-03 109.876190 126.360001 126.870003 124.660004 124.660004
# 2014-10-04        NaN        NaN        NaN        NaN        NaN
# 2014-10-05        NaN        NaN        NaN        NaN        NaN
# ...               ...        ...        ...        ...        ...
# 2021-05-27 250.699997 250.699997 252.600006 247.190002 248.110001
# 2021-05-28 247.020004 247.020004 248.979996 245.369995 247.479996
# 2021-05-29        NaN        NaN        NaN        NaN        NaN
# 2021-05-30        NaN        NaN        NaN        NaN        NaN
# 2021-05-31        NaN        NaN        NaN        NaN        NaN
#
#                                 BTC-USD                            \
# ...

# %%
df['BTC-USD']
# Out:
#               Adj Close        Close         High          Low         Open  \
# Date
# 2014-10-01   383.614990   383.614990   391.378998   380.779999   387.427002
# 2014-10-02   375.071991   375.071991   385.497009   372.946014   383.988007
# 2014-10-03   359.511993   359.511993   377.695007   357.859009   375.181000
# 2014-10-04   328.865997   328.865997   364.487000   325.885986   359.891998
# 2014-10-05   320.510010   320.510010   341.800995   289.295990   328.915985
# ...                 ...          ...          ...          ...          ...
# 2021-05-27 38436.968750 38436.968750 40379.617188 37247.902344 39316.890625
# 2021-05-28 35697.605469 35697.605469 38856.968750 34779.039062 38507.082031
# 2021-05-29 34616.066406 34616.066406 37234.500000 33693.929688 35684.156250
# 2021-05-30 35678.128906 35678.128906 36400.667969 33520.738281 34607.406250
# 2021-05-31 37332.855469 37332.855469 37468.250000 34241.945312 35658.593750
#
#                  Volume
# Date
# ...

# %%
# swap outer and inner index again
df = df.swaplevel(axis='columns').sort_index(axis='columns')
df
# Out:
#             Adj Close                                               \
#                    BA      BTC-USD EURUSD=X        GC=F       MSFT
# Date
# 2014-10-01 108.406677   383.614990 1.262834 1214.599976  40.099861
# 2014-10-02 107.971893   375.071991 1.262419 1214.199951  39.977543
# 2014-10-03 109.876190   359.511993 1.267058 1192.199951  40.265850
# 2014-10-04        NaN   328.865997      NaN         NaN        NaN
# 2014-10-05        NaN   320.510010      NaN         NaN        NaN
# ...               ...          ...      ...         ...        ...
# 2021-05-27 250.699997 38436.968750 1.219260 1895.699951 247.866714
# 2021-05-28 247.020004 35697.605469 1.219319 1902.500000 248.234558
# 2021-05-29        NaN 34616.066406      NaN         NaN        NaN
# 2021-05-30        NaN 35678.128906      NaN         NaN        NaN
# 2021-05-31        NaN 37332.855469 1.219007         NaN        NaN
#
#                              Close                                    ...  \
# ...

# %%
close = df.Close.copy()

# %%
close
# Out:
#                    BA      BTC-USD  EURUSD=X        GC=F       MSFT  \
# Date
# 2014-10-01 124.669998   383.614990  1.262834 1214.599976  45.900002
# 2014-10-02 124.169998   375.071991  1.262419 1214.199951  45.759998
# 2014-10-03 126.360001   359.511993  1.267058 1192.199951  46.090000
# 2014-10-04        NaN   328.865997       NaN         NaN        NaN
# 2014-10-05        NaN   320.510010       NaN         NaN        NaN
# ...               ...          ...       ...         ...        ...
# 2021-05-27 250.699997 38436.968750  1.219260 1895.699951 249.309998
# 2021-05-28 247.020004 35697.605469  1.219319 1902.500000 249.679993
# 2021-05-29        NaN 34616.066406       NaN         NaN        NaN
# 2021-05-30        NaN 35678.128906       NaN         NaN        NaN
# 2021-05-31        NaN 37332.855469  1.219007         NaN        NaN
#
#                    ^DJI
# Date
# 2014-10-01 16804.710938
# 2014-10-02 16801.050781
# 2014-10-03 17009.689453
# 2014-10-04          NaN
# ...

# %%
close.describe()
# Out:
#                BA      BTC-USD    EURUSD=X        GC=F        MSFT  \
# count 1677.000000  2435.000000 1736.000000 1674.000000 1677.000000
# mean   228.737961  7626.036370    1.140689 1372.014516  106.314377
# std     94.374231 11624.409033    0.050122  235.715391   60.772246
# min     95.010002   178.102997    1.039047 1050.800049   40.290001
# 25%    143.339996   535.391998    1.105461 1216.549988   54.830002
# 50%    189.080002  4370.810059    1.130039 1283.149963   89.709999
# 75%    335.160004  9207.506836    1.177749 1482.300018  138.899994
# max    440.619995 63503.457031    1.282166 2051.500000  261.970001
#
#               ^DJI
# count  1677.000000
# mean  23004.372736
# std    4659.921979
# min   15660.179688
# 25%   18086.400391
# 50%   23625.339844
# 75%   26289.980469
# max   34777.761719

# %%
close['BTC-USD'].dropna().plot(figsize=(15,8),fontsize=13)
plt.legend(fontsize=13)
plt.show()

# %%
close.dropna().plot(figsize=(15,8),fontsize=13)
plt.legend(fontsize=13)
plt.show()

# %%
# normalizing financial time series to a base value

# %%
close
close.iloc[0,0] # first price BA
close.BA.div(close.iloc[0,0]) # base value (1)
close.BA.div(close.iloc[0,0]).mul(100) # base value (100)
close.iloc[0] # first price for all tickers
# Out:
# BA           124.669998
# BTC-USD      383.614990
# EURUSD=X       1.262834
# GC=F        1214.599976
# MSFT          45.900002
# ^DJI       16804.710938
# Name: 2014-10-01 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
#                    BA      BTC-USD   EURUSD=X       GC=F       MSFT       ^DJI
# Date
# 2014-10-01 100.000000   100.000000 100.000000 100.000000 100.000000 100.000000
# 2014-10-02  99.598941    97.773028  99.967178  99.967065  99.694982  99.978219
# 2014-10-03 101.355581    93.716878 100.334500  98.155769 100.413940 101.219768
# 2014-10-04        NaN    85.728140        NaN        NaN        NaN        NaN
# 2014-10-05        NaN    83.549918        NaN        NaN        NaN        NaN
# ...               ...          ...        ...        ...        ...        ...
# 2021-05-27 201.090880 10019.673300  96.549498 156.076074 543.159018 205.089161
# 2021-05-28 198.139094  9305.581476  96.554199 156.635933 543.965108 205.474818
# 2021-05-29        NaN  9023.648003        NaN        NaN        NaN        NaN
# 2021-05-30        NaN  9300.504364        NaN        NaN        NaN        NaN
# 2021-05-31        NaN  9731.855224  96.529486        NaN        NaN        NaN
#
# ...

# %%
norm.dropna().plot(figsize=(15,8),fontsize=13, logy=True)
plt.legend(fontsize=13)
plt.show()

# %%
start_exercise = '2015-01-02'
end_exercise = '2020-12-31'
symbol_exercise = ['GE', 'BB.TO']

# %%
df_exercise = pd.DataFrame(yf.download(symbol_exercise,start_exercise,end_exercise))
df_exercise
# Out:
# [*********************100%***********************]  2 of 2 completed
#            Adj Close                Close                 High             \
#                BB.TO         GE     BB.TO         GE     BB.TO         GE
# Date
# 2015-01-02 12.740000 167.753311 12.740000 192.769226 13.000000 195.846161
# 2015-01-05 12.650000 164.674103 12.650000 189.230774 12.680000 192.384613
# 2015-01-06 12.570000 161.126144 12.570000 185.153839 12.770000 189.000000
# 2015-01-07 12.610000 161.193130 12.610000 185.230774 12.780000 187.615387
# 2015-01-08 12.590000 163.134399 12.590000 187.461533 12.750000 187.538467
# ...              ...        ...       ...        ...       ...        ...
# 2020-12-23  9.120000  86.528992  9.120000  86.879997  9.410000  87.839996
# 2020-12-24  9.060000  84.855782  9.060000  85.199997  9.290000  86.800003
# 2020-12-28       NaN  84.776115       NaN  85.120003       NaN  86.239998
# 2020-12-29  8.690000  84.138695  8.690000  84.480003  8.950000  86.160004
# ...

# %%
close_exercise = df_exercise['Close']['GE']
plt.plot(close_exercise)
plt.ylabel('Price')
plt.xlabel('Time')
plt.show()

# %%
norm_exercise = df_exercise['Close'].div(df_exercise['Close'].iloc[0]).mul(100)
# plt.plot(norm_exercise)
norm_exercise
# Out:
#                 BB.TO         GE
# Date
# 2015-01-02 100.000000 100.000000
# 2015-01-05  99.293562  98.164410
# 2015-01-06  98.665619  96.049480
# 2015-01-07  98.979591  96.089390
# 2015-01-08  98.822609  97.246607
# ...               ...        ...
# 2020-12-23  71.585558  45.069433
# 2020-12-24  71.114604  44.197924
# 2020-12-28        NaN  44.156427
# 2020-12-29  68.210359  43.824424
# 2020-12-30  66.797491  44.446929
#
# [1535 rows x 2 columns]

# %%
final_price_GE_exercise = norm_exercise['GE'][-1]
final_price_GE_exercise
# Out:
# 44.446928615145154

# %%
msft = close.MSFT.dropna().to_frame().copy()
msft
# Out:
#                  MSFT
# Date
# 2014-10-01  45.900002
# 2014-10-02  45.759998
# 2014-10-03  46.090000
# 2014-10-06  46.090000
# 2014-10-07  45.529999
# ...               ...
# 2021-05-24 250.779999
# 2021-05-25 251.720001
# 2021-05-26 251.490005
# 2021-05-27 249.309998
# 2021-05-28 249.679993
#
# [1677 rows x 1 columns]

# %%
msft.rename(columns={'MSFT':'Price'}, inplace=True)
msft
# Out:
#                 Price
# Date
# 2014-10-01  45.900002
# 2014-10-02  45.759998
# 2014-10-03  46.090000
# 2014-10-06  46.090000
# 2014-10-07  45.529999
# ...               ...
# 2021-05-24 250.779999
# 2021-05-25 251.720001
# 2021-05-26 251.490005
# 2021-05-27 249.309998
# 2021-05-28 249.679993
#
# [1677 rows x 1 columns]

# %%
msft.shift(periods=1)
msft['P_lag1'] = msft.shift(periods=1)
msft
# Out:
#                 Price     P_lag1
# Date
# 2014-10-01  45.900002        NaN
# 2014-10-02  45.759998  45.900002
# 2014-10-03  46.090000  45.759998
# 2014-10-06  46.090000  46.090000
# 2014-10-07  45.529999  46.090000
# ...               ...        ...
# 2021-05-24 250.779999 245.169998
# 2021-05-25 251.720001 250.779999
# 2021-05-26 251.490005 251.720001
# 2021-05-27 249.309998 251.490005
# 2021-05-28 249.679993 249.309998
#
# [1677 rows x 2 columns]

# %%
msft['P_diff'] = msft.Price.sub(msft.P_lag1)
msft
# Out:
#                 Price     P_lag1    P_diff
# Date
# 2014-10-01  45.900002        NaN       NaN
# 2014-10-02  45.759998  45.900002 -0.140003
# 2014-10-03  46.090000  45.759998  0.330002
# 2014-10-06  46.090000  46.090000  0.000000
# 2014-10-07  45.529999  46.090000 -0.560001
# ...               ...        ...       ...
# 2021-05-24 250.779999 245.169998  5.610001
# 2021-05-25 251.720001 250.779999  0.940002
# 2021-05-26 251.490005 251.720001 -0.229996
# 2021-05-27 249.309998 251.490005 -2.180008
# 2021-05-28 249.679993 249.309998  0.369995
#
# [1677 rows x 3 columns]

# %%
msft['P_diff2'] = msft.Price.diff(periods=1)
msft
# Out:
#                 Price     P_lag1    P_diff   P_diff2
# Date
# 2014-10-01  45.900002        NaN       NaN       NaN
# 2014-10-02  45.759998  45.900002 -0.140003 -0.140003
# 2014-10-03  46.090000  45.759998  0.330002  0.330002
# 2014-10-06  46.090000  46.090000  0.000000  0.000000
# 2014-10-07  45.529999  46.090000 -0.560001 -0.560001
# ...               ...        ...       ...       ...
# 2021-05-24 250.779999 245.169998  5.610001  5.610001
# 2021-05-25 251.720001 250.779999  0.940002  0.940002
# 2021-05-26 251.490005 251.720001 -0.229996 -0.229996
# 2021-05-27 249.309998 251.490005 -2.180008 -2.180008
# 2021-05-28 249.679993 249.309998  0.369995  0.369995
#
# [1677 rows x 4 columns]

# %%
msft.P_diff.equals(msft.P_diff2)
# Out:
# True

# %%
msft.Price.div(msft.P_lag1) - 1
# Out:
# Date
# 2014-10-01         NaN
# 2014-10-02   -0.003050
# 2014-10-03    0.007212
# 2014-10-06    0.000000
# 2014-10-07   -0.012150
#                 ...
# 2021-05-24    0.022882
# 2021-05-25    0.003748
# 2021-05-26   -0.000914
# 2021-05-27   -0.008668
# 2021-05-28    0.001484
# Length: 1677, dtype: float64

# %%
msft['Returns'] = msft.Price.pct_change(periods=1)
msft
# Out:
#                 Price     P_lag1    P_diff   P_diff2   Returns
# Date
# 2014-10-01  45.900002        NaN       NaN       NaN       NaN
# 2014-10-02  45.759998  45.900002 -0.140003 -0.140003 -0.003050
# 2014-10-03  46.090000  45.759998  0.330002  0.330002  0.007212
# 2014-10-06  46.090000  46.090000  0.000000  0.000000  0.000000
# 2014-10-07  45.529999  46.090000 -0.560001 -0.560001 -0.012150
# ...               ...        ...       ...       ...       ...
# 2021-05-24 250.779999 245.169998  5.610001  5.610001  0.022882
# 2021-05-25 251.720001 250.779999  0.940002  0.940002  0.003748
# 2021-05-26 251.490005 251.720001 -0.229996 -0.229996 -0.000914
# 2021-05-27 249.309998 251.490005 -2.180008 -2.180008 -0.008668
# 2021-05-28 249.679993 249.309998  0.369995  0.369995  0.001484
#
# [1677 rows x 5 columns]

# %%
msft.drop(columns=['P_lag1','P_diff','P_diff2'],inplace=True)
msft
# Out:
#                 Price   Returns
# Date
# 2014-10-01  45.900002       NaN
# 2014-10-02  45.759998 -0.003050
# 2014-10-03  46.090000  0.007212
# 2014-10-06  46.090000  0.000000
# 2014-10-07  45.529999 -0.012150
# ...               ...       ...
# 2021-05-24 250.779999  0.022882
# 2021-05-25 251.720001  0.003748
# 2021-05-26 251.490005 -0.000914
# 2021-05-27 249.309998 -0.008668
# 2021-05-28 249.679993  0.001484
#
# [1677 rows x 2 columns]

# %%
msft.Price.plot(figsize=(15,8),fontsize=13)
plt.legend(fontsize=13)

# %%
msft.describe()
# Out:
#             Price     Returns
# count 1677.000000 1676.000000
# mean   106.314377    0.001160
# std     60.772246    0.017256
# min     40.290001   -0.147390
# 25%     54.830002   -0.006177
# 50%     89.709999    0.000918
# 75%    138.899994    0.009110
# max    261.970001    0.142169

# %%
mu = msft.Returns.mean() # arithmetic mean return -> Reward
mu
# Out:
# 106.31437686972484

# %%
sigma = msft.Returns.std() # std of returns -> Risk/Volatility
sigma
# Out:
# 0.0172560784334779

# %%
np.sqrt(msft.Returns.var())
# Out:
# 0.0172560784334779

# %%
btc = df.Close['BTC-USD'].dropna().to_frame().copy()
btc
btc.rename(columns={'BTC-USD':'Price'},inplace=True)
btc['P_1'] = btc.Price.shift(periods=1)
btc = btc.iloc[1:]
btc['P_diff'] = btc.Price.diff(periods=1)
btc['P_dif2'] = btc.Price.pct_change(periods=1)
btc.rename(columns={'P_dif2':'Daily Returns'},inplace=True)
btc
# Out:
#                   Price          P_1       P_diff  Daily Returns
# Date
# 2014-10-02   375.071991   383.614990          NaN            NaN
# 2014-10-03   359.511993   375.071991   -15.559998      -0.041485
# 2014-10-04   328.865997   359.511993   -30.645996      -0.085243
# 2014-10-05   320.510010   328.865997    -8.355988      -0.025408
# 2014-10-06   330.079010   320.510010     9.569000       0.029856
# ...                 ...          ...          ...            ...
# 2021-05-27 38436.968750 39294.199219  -857.230469      -0.021816
# 2021-05-28 35697.605469 38436.968750 -2739.363281      -0.071269
# 2021-05-29 34616.066406 35697.605469 -1081.539062      -0.030297
# 2021-05-30 35678.128906 34616.066406  1062.062500       0.030681
# 2021-05-31 37332.855469 35678.128906  1654.726562       0.046379
#
# [2434 rows x 4 columns]

# %%
btc.drop(columns=(['P_1','P_diff']),inplace=True)
btc
# Out:
#                   Price  Daily Returns
# Date
# 2014-10-02   375.071991            NaN
# 2014-10-03   359.511993      -0.041485
# 2014-10-04   328.865997      -0.085243
# 2014-10-05   320.510010      -0.025408
# 2014-10-06   330.079010       0.029856
# ...                 ...            ...
# 2021-05-27 38436.968750      -0.021816
# 2021-05-28 35697.605469      -0.071269
# 2021-05-29 34616.066406      -0.030297
# 2021-05-30 35678.128906       0.030681
# 2021-05-31 37332.855469       0.046379
#
# [2434 rows x 2 columns]

# %%
btc['Daily Returns'].mean()
# Out:
# 0.00266597248750741

# %%
btc['Daily Returns'].std()
# Out:
# 0.03912730889207418

# %%
# investment multiple and CAGR (compound annual growth rate)

# %%
msft
# Out:
#                 Price   Returns
# Date
# 2014-10-01  45.900002       NaN
# 2014-10-02  45.759998 -0.003050
# 2014-10-03  46.090000  0.007212
# 2014-10-06  46.090000  0.000000
# 2014-10-07  45.529999 -0.012150
# ...               ...       ...
# 2021-05-24 250.779999  0.022882
# 2021-05-25 251.720001  0.003748
# 2021-05-26 251.490005 -0.000914
# 2021-05-27 249.309998 -0.008668
# 2021-05-28 249.679993  0.001484
#
# [1677 rows x 2 columns]

# %%
# investment multiple - ending value{
  "parameters": {
    "plot": {
      "lines": [
        {
          "show": true,
          "color": "red",
          "label": "Pressure",
          "attribute": "measuredPressure",
          "colorDark": "red",
          "yAxisName": "pressure"
        },
        {
          "show": true,
          "color": "#000000",
          "label": "Velocity",
          "attribute": "cumShearFracsVelocity",
          "colorDark": "#A5D6A7",
          "yAxisName": "cumShearFracs"
        },
        {
          "show": true,
          "color": "#000000",
          "label": "Guidance",
          "attribute": "guidance",
          "colorDark": "#E8EAF6",
          "yAxisName": "rate"
        },
        {
          "show": true,
          "color": "",
          "label": "PS",
          "attribute": "pseudoProppant",
          "colorDark": "#E8F5E9",
          "yAxisName": "proppant"
        },
        {
          "show": true,
          "color": "green",
          "label": "Predicted Pressure",
          "attribute": "predictedPressure",
          "colorDark": "#7CB342",
          "yAxisName": "pressure"
        },
        {
          "show": false,
          "color": "#D81B60",
          "label": "Pressure 1H",
          "attribute": "1H ShearFrac (psi)",
          "colorDark": "#F06292",
          "yAxisName": "pressure"
        },
        {
          "show": false,
          "color": "#1A237E",
          "label": "Pressure 3H",
          "attribute": "3H ShearFrac (psi)",
          "colorDark": "#7986CB",
          "yAxisName": "pressure"
        },
        {
          "show": true,
          "color": "blue",
          "label": "Slurry Rate",
          "attribute": "slurryRate",
          "colorDark": "#1ED1E5",
          "yAxisName": "rate"
        },
        {
          "show": true,
          "color": "darkmagenta",
          "label": "Tensile Frac",
          "attribute": "tensileFrac",
          "colorDark": "darkmagenta",
          "yAxisName": "shearFracs"
        },
        {
          "show": true,
          "color": "green",
          "label": "Shear Fracs",
          "attribute": "shearFracs",
          "colorDark": "green",
          "yAxisName": "shearFracs"
        },
        {
          "show": true,
          "color": "#795548",
          "label": "Blender Prop Conc",
          "attribute": "BL1 Prop Conc (ppg)",
          "colorDark": "#FFEB3B",
          "yAxisName": "proppant"
        },
        {
          "show": true,
          "color": "orange",
          "label": "SFG BH Proppant Conc",
          "attribute": "sfgBHSand",
          "colorDark": "orange",
          "yAxisName": "proppant"
        },
        {
          "show": true,
          "color": "black",
          "label": "Frac Block Size",
          "attribute": "fracBlockSize",
          "colorDark": "#FFEBEE",
          "yAxisName": "fracBlockSize"
        },
        {
          "show": true,
          "color": "cyan",
          "label": "Cumulative Tensile",
          "attribute": "tensileSum",
          "colorDark": "cyan",
          "yAxisName": "cumShearFracs"
        },
        {
          "show": true,
          "color": "purple",
          "label": "Cumulative Shear Frac",
          "attribute": "cumShearFracs",
          "colorDark": "#9C27B0",
          "yAxisName": "cumShearFracs"
        },
        {
          "show": false,
          "color": "#FAFAFA",
          "label": "Cumulative Sand",
          "attribute": "Proppant Total (lbs)",
          "colorDark": "#212121",
          "yAxisName": "proppant"
        },
        {
          "show": false,
          "color": "lime",
          "label": "FR1 Conc (gal/Mgal)",
          "attribute": "S2_Chem_2_FR Ratio (gal/Mgal)",
          "colorDark": "lime",
          "yAxisName": "proppant"
        }
      ],
      "yAxes": [
        {
          "name": "pressure",
          "unit": "psi",
          "title": "Pressure",
          "limits": {
            "max": 12000,
            "min": 0
          },
          "position": "left"
        },
        {
          "name": "rate",
          "unit": "bpm",
          "title": "Slurry Rate",
          "limits": {
            "max": 120,
            "min": 0
          },
          "position": "left"
        },
        {
          "name": "proppant",
          "unit": "ppg",
          "title": "Proppant",
          "limits": {
            "max": 6,
            "min": 0
          },
          "position": "right"
        },
        {
          "name": "cumShearFracs",
          "unit": "",
          "title": "Cumulative Shear Fracs",
          "limits": {
            "max": 600000,
            "min": 0
          },
          "position": "right"
        },
        {
          "name": "shearFracs",
          "unit": "",
          "title": "Shear Fracs",
          "limits": {
            "max": 2,
            "min": 0
          },
          "position": "right"
        },
        {
          "name": "fracBlockSize",
          "unit": "",
          "title": "Block Size",
          "limits": {
            "max": 1.2,
            "min": 0
          },
          "position": "right"
        }
      ],
      "useUTC": true,
      "endTime": 1607070059393,
      "startTime": 0
    },
    "source": {
      "attributes": [
        {
          "name": "time",
          "unit": "milliseconds",
          "index": 0,
          "multiplier": 1
        },
        {
          "name": "pressure",
          "unit": "psi",
          "index": 7,
          "multiplier": 1
        },
        {
          "name": "rate",
          "unit": "bpm",
          "index": 18,
          "multiplier": 1
        },
        {
          "name": "cleanRate",
          "unit": "bpm",
          "index": 21,
          "multiplier": 1
        },
        {
          "name": "proppant",
          "unit": "ppg",
          "index": 33,
          "multiplier": 1
        },
        {
          "name": "frictionreducer",
          "unit": "gal/mgal",
          "index": 60,
          "multiplier": 1
        },
        {
          "name": "mesh40",
          "unit": "none",
          "index": 17,
          "multiplier": 1
        },
        {
          "name": "mesh100",
          "unit": "none",
          "index": 5,
          "multiplier": 1
        }
      ]
    },
    "fbsFlag": true,
    "meshLag": 0,
    "rateClip": 20,
    "sandBase": 0.1,
    "sandShift": 0,
    "guideWidth": 20,
    "sandWindow": 0,
    "pressureBase": 1000,
    "cumShearStart": 1607063044255,
    "minPseudoSand": 0.1,
    "pressureShift": 4,
    "boreholeVolume": 486.2837975,
    "guideRateDelta": 1,
    "panicRateDelta": 1,
    "regrCoeff2Sand": 0.05,
    "regrYIntercept": 0.6,
    "velocityWindow": 300,
    "blockSizeHurdle": 0.02,
    "frequencyWindow": 50,
    "pressureCaution": 0.99,
    "pressureCeiling": 11000,
    "regrCoeff1Water": 0.5,
    "pressureIncrease": 100,
    "rateMessageDelay": 60,
    "rateStepVariance": 1,
    "tensileStartTime": 1607062257384,
    "blockSizeSmoother": 50,
    "fracAmplitudeBias": 0.2,
    "guidanceStartTime": 0,
    "minimumRateChange": 0.3,
    "showClientGuidance": false,
    "boreholeVolumeUnits": "Field",
    "downholeconcentrates": [
      {
        "name": "proppant",
        "unit": "ppg",
        "output": "sfgBHSand",
        "multiplier": 1
      }
    ],
    "pseudoProppantWindow": 150,
    "cumShearFracsVelocityN": 300,
    "yInterceptOverrideTime": 0,
    "derivativePercentIncrease": 1.5,
    "cumShearFracsVelocityScalar": 12,
    "predictivePressureSmoothing": false,
    "boreholeMidPerfMeasuredDepth": 21251.25
  }
}
# Out:
#   File "C:\Users\AndreyIchshenko\AppData\Local\Temp\ipykernel_20428\3647035097.py", line 2
#     "parameters": {
#     ^
# IndentationError: unexpected indent
